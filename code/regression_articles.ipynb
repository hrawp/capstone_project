# %% [markdown]
# # Predicting Senitment Analysis with Regression
# **Author:** AARON
# **Date:** March 29, 2026
# **Objective:** Create a Regression Model to predict Sentiment Analysis for articles.

# %% [markdown]
# ## Introduction
# - Using the Medical Cost Personal Dataset, decide what inputs to use in Regression model to predict Medical Claims.
# - Try alternate methods or engineered variables to find an optimal model.

# %% [markdown]
# ## Section 1. Import and Inspect the Data

# %% [markdown]
# ### 1.1 Include Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Import scatter_matrix for data exploration
from pandas.plotting import scatter_matrix

#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression, Ridge, ElasticNet
#from sklearn.preprocessing import PolynomialFeatures
#from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ### 1.2 Load the dataset and display basic information

# %%
# Load the article dataset 
df = pd.read_csv("iran_war_complete_articles_sentiment.csv")
df = df[df['iran_count'] != 0]

# Display structure and first few rows
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 366 entries, 0 to 401
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Key                         366 non-null    int64
#  1   title                       366 non-null    object
#  2   headline_length             366 non-null    int64
#  3   article_word_count          366 non-null    int64
#  4   author                      366 non-null    object
#  5   publisher                   366 non-null    object
#  6   publisher_country           366 non-null    object
#  7   publisher_type              366 non-null    object
#  8   published_date              366 non-null    object
#  9   collection_date             366 non-null    object
#  10  link                        366 non-null    object
#  11  full_text                   366 non-null    object
#  12  source_type                 366 non-null    object
#  13  keyword_trigger             366 non-null    object
#  14  start_text                  366 non-null    object
#  15  half_text                   366 non-null    object
#  16  canonical_link              366 non-null    object
#  17  _row_id                     366 non-null    object
#  18  iran_count                  366 non-null    float64
#  19  iran_score                  366 non-null    float64
#  20  iran_sentiment              366 non-null    object
#  21  iranian_count               366 non-null    float64
#  22  iranian_score               260 non-null    float64
#  23  iranian_sentiment           366 non-null    object
#  24  israel_israeli_count        366 non-null    float64
#  25  israel_israeli_score        314 non-null    float64
#  26  israel_israeli_sentiment    366 non-null    object
#  27  hormuz_count                366 non-null    float64
#  28  hormuz_score                189 non-null    float64
#  29  hormuz_sentiment            366 non-null    object
#  30  supreme_leader_count        366 non-null    float64
#  31  supreme_leader_score        81 non-null     float64
#  32  supreme_leader_sentiment    366 non-null    object
#  33  tehran_count                366 non-null    float64
#  34  tehran_score                166 non-null    float64
#  35  tehran_sentiment            366 non-null    object
#  36  trump_count                 366 non-null    float64
#  37  trump_score                 232 non-null    float64
#  38  trump_sentiment             366 non-null    object
#  39  us_united_states_count      366 non-null    float64
#  40  us_united_states_score      349 non-null    float64
#  41  us_united_states_sentiment  366 non-null    object
#  42  title_score                 366 non-null    float64
#  43  title_sentiment             366 non-null    object
#  44  full_text_score             366 non-null    float64
#  45  full_text_sentiment         366 non-null    object
#  46  start_text_score            366 non-null    float64
#  47  start_text_sentiment        366 non-null    object
#  48  half_text_score             366 non-null    float64
#  49  half_text_sentiment         366 non-null    object
#  50  title_article_diff          366 non-null    float64
#  51  title_article_diff_label    366 non-null    object
# dtypes: float64(21), int64(3), object(28)
# memory usage: 151.5+ KB
#     Key                                              title  headline_length  \
# 0  2416  How a prolonged Middle East conflict could res...               61
# 1  2404  War on Iran: What troops is the US moving to t...               54
# 2  2104  The US-Israeli strategy against Iran is workin...               60
# 3  2100  How badly has the Iran war hit the global econ...               70
# 4  2256  What US-Israeli targets reveal about Iran war ...               66
#
#    article_word_count                  author   publisher publisher_country  \
# 0                2455  Theo Leggett Transport         BBC                UK
# 1                2136            Abid Hussain  Al Jazeera             Qatar
# 2                2064          Muhanad Seloom  Al Jazeera             Qatar
# 3                2219        Priyanka Shankar  Al Jazeera             Qatar
# 4                2042        Joseph Stepansky  Al Jazeera             Qatar
#
#           publisher_type published_date collection_date  ... title_score  \
# 0     Public Broadcaster      3/26/2026       3/26/2026  ...      0.9860
# 1  International Network      3/25/2026       3/25/2026  ...     -0.9955
# 2  International Network      3/16/2026       3/16/2026  ...      0.9971
# 3  International Network      3/16/2026       3/16/2026  ...     -0.0009
# 4  International Network      3/20/2026       3/20/2026  ...     -0.9622
#
#   title_sentiment full_text_score full_text_sentiment start_text_score  \
# 0   very positive          0.1128             neutral           0.0942
# 1   very negative          0.1828   somewhat positive          -0.3291
# 2   very positive         -0.5135            negative          -0.3330
# 3         neutral         -0.3936             neutral          -0.6328
# 4   very negative         -0.5531            negative          -0.1419
#
#   start_text_sentiment half_text_score half_text_sentiment  \
# 0              neutral         -0.3486   somewhat negative
# 1    somewhat negative          0.0025             neutral
# 2    somewhat negative         -0.3678   somewhat negative
# 3             negative         -0.3801   somewhat negative
# 4              neutral         -0.6223            negative
#
#    title_article_diff  title_article_diff_label
# 0              0.8732  title much more positive
# 1             -1.1783  title much more negative
# 2              1.5106  title much more positive
# 3              0.3927  title much more positive
# 4             -0.4091  title much more negative
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 1.3 Check for missing values and display summary statistics

# %%
# Check for missing values using the isnull() method and then the sum() method. 
df.isnull().sum()
# Out:
# Key                             0
# title                           0
# headline_length                 0
# article_word_count              0
# author                          0
# publisher                       0
# publisher_country               0
# publisher_type                  0
# published_date                  0
# collection_date                 0
# link                            0
# full_text                       0
# source_type                     0
# keyword_trigger                 0
# start_text                      0
# half_text                       0
# canonical_link                  0
# _row_id                         0
# iran_count                      0
# iran_score                      0
# iran_sentiment                  0
# iranian_count                   0
# iranian_score                 106
# iranian_sentiment               0
# israel_israeli_count            0
# israel_israeli_score           52
# israel_israeli_sentiment        0
# hormuz_count                    0
# hormuz_score                  177
# hormuz_sentiment                0
# supreme_leader_count            0
# supreme_leader_score          285
# supreme_leader_sentiment        0
# tehran_count                    0
# tehran_score                  200
# tehran_sentiment                0
# trump_count                     0
# trump_score                   134
# trump_sentiment                 0
# us_united_states_count          0
# us_united_states_score         17
# us_united_states_sentiment      0
# title_score                     0
# title_sentiment                 0
# full_text_score                 0
# full_text_sentiment             0
# start_text_score                0
# start_text_sentiment            0
# half_text_score                 0
# half_text_sentiment             0
# title_article_diff              0
# title_article_diff_label        0
# dtype: int64

# %%
# Display summary statistics using the describe() method

print(df.describe())
# Out:
#                Key  headline_length  article_word_count  iran_count  \
# count   366.000000       366.000000          366.000000  366.000000
# mean   2997.185792        74.019126          756.467213    7.087432
# std    1865.699651        15.748265          374.558389    5.546121
# min    1002.000000        15.000000           55.000000    1.000000
# 25%    2103.250000        65.000000          495.750000    3.000000
# 50%    2261.500000        73.000000          668.000000    6.000000
# 75%    2427.250000        85.000000          964.500000    9.750000
# max    7068.000000       121.000000         2455.000000   32.000000
#
#        iran_score  iranian_count  iranian_score  israel_israeli_count  \
# count  366.000000     366.000000     260.000000            366.000000
# mean    -0.428887       2.439891      -0.353605              4.349727
# std      0.484899       2.596192       0.657644              5.175611
# min     -0.999200       0.000000      -0.999500              0.000000
# 25%     -0.978675       0.000000      -0.994050              1.000000
# 50%     -0.474150       2.000000      -0.447300              2.000000
# 75%     -0.110650       4.000000       0.000150              5.750000
# max      0.997400      13.000000       0.998500             35.000000
#
#        israel_israeli_score  hormuz_count  ...  tehran_score  trump_count  \
# count            314.000000    366.000000  ...     166.00000   366.000000
# mean              -0.513702      1.478142  ...      -0.34327     3.284153
# std                0.584906      2.202940  ...       0.77620     4.816196
# min               -0.999000      0.000000  ...      -0.99950     0.000000
# 25%               -0.993850      0.000000  ...      -0.99450     0.000000
# 50%               -0.692900      1.000000  ...      -0.78100     1.000000
# 75%               -0.238950      2.000000  ...       0.32095     5.000000
# max                0.998700     14.000000  ...       0.99850    34.000000
#
#        trump_score  us_united_states_count  us_united_states_score  \
# count   232.000000              366.000000              349.000000
# mean     -0.248784                6.338798               -0.272533
# std       0.677476                5.307526                0.541275
# min      -0.999500                0.000000               -0.999300
# 25%      -0.955500                3.000000               -0.686300
# 50%      -0.333200                5.000000               -0.309600
# 75%       0.139475                9.000000                0.001200
# max       0.998700               31.000000                0.998700
#
#        title_score  full_text_score  start_text_score  half_text_score  \
# count   366.000000       366.000000        366.000000       366.000000
# mean     -0.426091        -0.243050         -0.253295        -0.233644
# std       0.864440         0.321271          0.404976         0.337598
# min      -0.999500        -0.996800         -0.996700        -0.996800
# 25%      -0.997600        -0.458125         -0.597150        -0.458925
# 50%      -0.993750        -0.240700         -0.268650        -0.252800
# 75%       0.902950        -0.049375          0.004900        -0.019650
# max       0.998700         0.685900          0.997800         0.685900
#
#        title_article_diff
# count          366.000000
# mean            -0.183041
# std              0.870117
# min             -1.600900
# 25%             -0.824650
# 50%             -0.521900
# 75%              0.570525
# max              1.985000
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Reflection 1:
# What do you notice about the dataset? The dataset is fully populated with 1338 records.
# Are there any data issues?  There were no missing values.

# %% [markdown]
# ## Section 2. Data Exploration and Preparation
# ### 2.1 Explore Data Patterns and Distributions
#
# Map Sex and Smoker attributes to numeric numbers.
# Use one hop encoding for regions.

# %%
# Iran.
sns.boxplot(x='publisher', y='iran_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='iran_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='iranian_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='iranian_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='israel_israeli_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='israel_israeli_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='hormuz_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='hormuz_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='trump_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='trump_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='us_united_states_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='us_united_states_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='title_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='title_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='full_text_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='full_text_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='start_text_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='start_text_score'>

# %%
# Iran.
sns.boxplot(x='publisher', y='half_text_score', data=df)
# Out:
# <Axes: xlabel='publisher', ylabel='half_text_score'>

# %%
# Display summary statistics using the describe() method
print(df.describe())
# Out:
#                Key  headline_length  article_word_count  iran_count  \
# count   366.000000       366.000000          366.000000  366.000000
# mean   2997.185792        74.019126          756.467213    7.087432
# std    1865.699651        15.748265          374.558389    5.546121
# min    1002.000000        15.000000           55.000000    1.000000
# 25%    2103.250000        65.000000          495.750000    3.000000
# 50%    2261.500000        73.000000          668.000000    6.000000
# 75%    2427.250000        85.000000          964.500000    9.750000
# max    7068.000000       121.000000         2455.000000   32.000000
#
#        iran_score  iranian_count  iranian_score  israel_israeli_count  \
# count  366.000000     366.000000     260.000000            366.000000
# mean    -0.428887       2.439891      -0.353605              4.349727
# std      0.484899       2.596192       0.657644              5.175611
# min     -0.999200       0.000000      -0.999500              0.000000
# 25%     -0.978675       0.000000      -0.994050              1.000000
# 50%     -0.474150       2.000000      -0.447300              2.000000
# 75%     -0.110650       4.000000       0.000150              5.750000
# max      0.997400      13.000000       0.998500             35.000000
#
#        israel_israeli_score  hormuz_count  ...  tehran_score  trump_count  \
# count            314.000000    366.000000  ...     166.00000   366.000000
# mean              -0.513702      1.478142  ...      -0.34327     3.284153
# std                0.584906      2.202940  ...       0.77620     4.816196
# min               -0.999000      0.000000  ...      -0.99950     0.000000
# 25%               -0.993850      0.000000  ...      -0.99450     0.000000
# 50%               -0.692900      1.000000  ...      -0.78100     1.000000
# 75%               -0.238950      2.000000  ...       0.32095     5.000000
# max                0.998700     14.000000  ...       0.99850    34.000000
#
#        trump_score  us_united_states_count  us_united_states_score  \
# count   232.000000              366.000000              349.000000
# mean     -0.248784                6.338798               -0.272533
# std       0.677476                5.307526                0.541275
# min      -0.999500                0.000000               -0.999300
# 25%      -0.955500                3.000000               -0.686300
# 50%      -0.333200                5.000000               -0.309600
# 75%       0.139475                9.000000                0.001200
# max       0.998700               31.000000                0.998700
#
#        title_score  full_text_score  start_text_score  half_text_score  \
# count   366.000000       366.000000        366.000000       366.000000
# mean     -0.426091        -0.243050         -0.253295        -0.233644
# std       0.864440         0.321271          0.404976         0.337598
# min      -0.999500        -0.996800         -0.996700        -0.996800
# 25%      -0.997600        -0.458125         -0.597150        -0.458925
# 50%      -0.993750        -0.240700         -0.268650        -0.252800
# 75%       0.902950        -0.049375          0.004900        -0.019650
# max       0.998700         0.685900          0.997800         0.685900
#
#        title_article_diff
# count          366.000000
# mean            -0.183041
# std              0.870117
# min             -1.600900
# 25%             -0.824650
# 50%             -0.521900
# 75%              0.570525
# max              1.985000
#
# [8 rows x 24 columns]

# %%
# Check for correlations using the corr() method and tell it to use only the numeric features. 
print(df.corr(numeric_only=True))
# Out:
#                              Key  headline_length  article_word_count  \
# Key                     1.000000         0.288162           -0.117581
# headline_length         0.288162         1.000000           -0.117162
# article_word_count     -0.117581        -0.117162            1.000000
# iran_count             -0.003825        -0.113006            0.587809
# iran_score              0.143156         0.017536           -0.031828
# iranian_count           0.160442         0.002072            0.380410
# iranian_score           0.100405         0.006781           -0.048560
# israel_israeli_count   -0.096872        -0.081494            0.205955
# israel_israeli_score    0.043499         0.002687           -0.079197
# hormuz_count           -0.083852        -0.064547            0.395180
# hormuz_score            0.059500        -0.102214           -0.012083
# supreme_leader_count    0.050959         0.018372            0.125023
# supreme_leader_score    0.149766         0.149154           -0.113065
# tehran_count           -0.037586        -0.089988            0.327748
# tehran_score            0.045834        -0.092101           -0.009027
# trump_count            -0.126575         0.002421            0.314565
# trump_score             0.090768        -0.027214           -0.104430
# us_united_states_count -0.110491        -0.096740            0.560384
# us_united_states_score  0.107377         0.029341            0.030349
# title_score            -0.038781        -0.000007            0.088714
# full_text_score         0.156139         0.000744            0.006763
# start_text_score        0.101078        -0.040633            0.040807
# half_text_score         0.150896        -0.013468            0.031415
# title_article_diff     -0.096179        -0.000282            0.085638
#
#                         iran_count  iran_score  iranian_count  iranian_score  \
# Key                      -0.003825    0.143156       0.160442       0.100405
# headline_length          -0.113006    0.017536       0.002072       0.006781
# article_word_count        0.587809   -0.031828       0.380410      -0.048560
# iran_count                1.000000    0.069357       0.577850      -0.052957
# iran_score                0.069357    1.000000       0.067607       0.341223
# iranian_count             0.577850    0.067607       1.000000       0.002881
# iranian_score            -0.052957    0.341223       0.002881       1.000000
# israel_israeli_count      0.108599   -0.239271       0.044999      -0.205984
# israel_israeli_score     -0.054050    0.382785      -0.097882       0.043978
# hormuz_count              0.376882   -0.005456       0.160965       0.032823
# hormuz_score             -0.049041    0.172159      -0.095579       0.357053
# supreme_leader_count      0.229401    0.100191       0.226561       0.071431
# supreme_leader_score      0.046551    0.521438      -0.022023       0.234163
# tehran_count              0.452230    0.028486       0.439642      -0.040147
# tehran_score              0.048856    0.361942       0.025590       0.310084
# trump_count               0.349646   -0.003898       0.082222       0.035723
# trump_score              -0.128434    0.267111      -0.084878       0.089758
# us_united_states_count    0.639522    0.034987       0.338894      -0.020870
# us_united_states_score   -0.023073    0.431917      -0.036455       0.285807
# title_score               0.034140    0.101935       0.041145       0.098974
# full_text_score          -0.025885    0.535647      -0.012220       0.408589
# start_text_score          0.015430    0.480705      -0.023653       0.468646
# half_text_score           0.002803    0.525567       0.008990       0.414959
# title_article_diff        0.043475   -0.096506       0.045389      -0.037857
#
#                         israel_israeli_count  israel_israeli_score  \
# Key                                -0.096872              0.043499
# headline_length                    -0.081494              0.002687
# article_word_count                  0.205955             -0.079197
# iran_count                          0.108599             -0.054050
# iran_score                         -0.239271              0.382785
# iranian_count                       0.044999             -0.097882
# iranian_score                      -0.205984              0.043978
# israel_israeli_count                1.000000             -0.085092
# israel_israeli_score               -0.085092              1.000000
# hormuz_count                       -0.095445              0.002423
# hormuz_score                       -0.049287             -0.056580
# supreme_leader_count                0.134968              0.071432
# supreme_leader_score               -0.273012              0.328774
# tehran_count                        0.132548             -0.067854
# tehran_score                       -0.089197              0.157229
# trump_count                        -0.081265              0.063244
# trump_score                        -0.094767              0.157717
# us_united_states_count             -0.027065             -0.005396
# us_united_states_score             -0.230387              0.314174
# title_score                        -0.100206              0.126865
# full_text_score                    -0.370871              0.391709
# start_text_score                   -0.344942              0.371875
# half_text_score                    -0.345254              0.394798
# title_article_diff                  0.037384             -0.018997
#
#                         hormuz_count  ...  tehran_score  trump_count  \
# Key                        -0.083852  ...      0.045834    -0.126575
# headline_length            -0.064547  ...     -0.092101     0.002421
# article_word_count          0.395180  ...     -0.009027     0.314565
# iran_count                  0.376882  ...      0.048856     0.349646
# iran_score                 -0.005456  ...      0.361942    -0.003898
# iranian_count               0.160965  ...      0.025590     0.082222
# iranian_score               0.032823  ...      0.310084     0.035723
# israel_israeli_count       -0.095445  ...     -0.089197    -0.081265
# israel_israeli_score        0.002423  ...      0.157229     0.063244
# hormuz_count                1.000000  ...     -0.005643     0.385344
# hormuz_score                0.116940  ...      0.241587    -0.084395
# supreme_leader_count        0.023644  ...      0.150127     0.005311
# supreme_leader_score        0.008963  ...      0.032055     0.151919
# tehran_count                0.153538  ...      0.008726     0.088762
# tehran_score               -0.005643  ...      1.000000    -0.113012
# trump_count                 0.385344  ...     -0.113012     1.000000
# trump_score                -0.078967  ...      0.152640    -0.067697
# us_united_states_count      0.353758  ...     -0.121330     0.527404
# us_united_states_score      0.031366  ...      0.233296     0.033449
# title_score                 0.116563  ...     -0.006921     0.060860
# full_text_score             0.051122  ...      0.375672     0.046344
# start_text_score            0.076709  ...      0.386368     0.096027
# half_text_score             0.052331  ...      0.407178     0.091056
# title_article_diff          0.096927  ...     -0.129652     0.043352
#
#                         trump_score  us_united_states_count  \
# Key                        0.090768               -0.110491
# headline_length           -0.027214               -0.096740
# article_word_count        -0.104430                0.560384
# iran_count                -0.128434                0.639522
# iran_score                 0.267111                0.034987
# iranian_count             -0.084878                0.338894
# iranian_score              0.089758               -0.020870
# israel_israeli_count      -0.094767               -0.027065
# israel_israeli_score       0.157717               -0.005396
# hormuz_count              -0.078967                0.353758
# hormuz_score               0.184308               -0.043938
# supreme_leader_count      -0.110990                0.110589
# supreme_leader_score      -0.073060               -0.009735
# tehran_count              -0.025685                0.240722
# tehran_score               0.152640               -0.121330
# trump_count               -0.067697                0.527404
# trump_score                1.000000               -0.081948
# us_united_states_count    -0.081948                1.000000
# us_united_states_score     0.350328                0.020474
# title_score               -0.033243                0.034122
# full_text_score            0.331925                0.055859
# start_text_score           0.271902                0.101709
# half_text_score            0.318716                0.096257
# title_article_diff        -0.141089                0.013274
#
#                         us_united_states_score  title_score  full_text_score  \
# Key                                   0.107377    -0.038781         0.156139
# headline_length                       0.029341    -0.000007         0.000744
# article_word_count                    0.030349     0.088714         0.006763
# iran_count                           -0.023073     0.034140        -0.025885
# iran_score                            0.431917     0.101935         0.535647
# iranian_count                        -0.036455     0.041145        -0.012220
# iranian_score                         0.285807     0.098974         0.408589
# israel_israeli_count                 -0.230387    -0.100206        -0.370871
# israel_israeli_score                  0.314174     0.126865         0.391709
# hormuz_count                          0.031366     0.116563         0.051122
# hormuz_score                          0.114576     0.047228         0.191308
# supreme_leader_count                  0.034468     0.105789         0.057611
# supreme_leader_score                  0.341509     0.158980         0.424110
# tehran_count                         -0.079521     0.105530        -0.092864
# tehran_score                          0.233296    -0.006921         0.375672
# trump_count                           0.033449     0.060860         0.046344
# trump_score                           0.350328    -0.033243         0.331925
# us_united_states_count                0.020474     0.034122         0.055859
# us_united_states_score                1.000000     0.092050         0.530080
# title_score                           0.092050     1.000000         0.168097
# full_text_score                       0.530080     0.168097         1.000000
# start_text_score                      0.461642     0.181302         0.807103
# half_text_score                       0.523216     0.180731         0.957065
# title_article_diff                   -0.098106     0.931409        -0.202227
#
#                         start_text_score  half_text_score  title_article_diff
# Key                             0.101078         0.150896           -0.096179
# headline_length                -0.040633        -0.013468           -0.000282
# article_word_count              0.040807         0.031415            0.085638
# iran_count                      0.015430         0.002803            0.043475
# iran_score                      0.480705         0.525567           -0.096506
# iranian_count                  -0.023653         0.008990            0.045389
# iranian_score                   0.468646         0.414959           -0.037857
# israel_israeli_count           -0.344942        -0.345254            0.037384
# israel_israeli_score            0.371875         0.394798           -0.018997
# hormuz_count                    0.076709         0.052331            0.096927
# hormuz_score                    0.181517         0.201724           -0.009381
# supreme_leader_count           -0.027197         0.055111            0.083828
# supreme_leader_score            0.254532         0.411413            0.020796
# tehran_count                   -0.083733        -0.067687            0.139129
# tehran_score                    0.386368         0.407178           -0.129652
# trump_count                     0.096027         0.091056            0.043352
# trump_score                     0.271902         0.318716           -0.141089
# us_united_states_count          0.101709         0.096257            0.013274
# us_united_states_score          0.461642         0.523216           -0.098106
# title_score                     0.181302         0.180731            0.931409
# full_text_score                 0.807103         0.957065           -0.202227
# start_text_score                1.000000         0.844429           -0.117886
# half_text_score                 0.844429         1.000000           -0.173823
# title_article_diff             -0.117886        -0.173823            1.000000
#
# [24 rows x 24 columns]

# %%
# Check for missing values using the isnull() method and then the sum() method. 
df.isnull().sum()
# Out:
# Key                             0
# title                           0
# headline_length                 0
# article_word_count              0
# author                          0
# publisher                       0
# publisher_country               0
# publisher_type                  0
# published_date                  0
# collection_date                 0
# link                            0
# full_text                       0
# source_type                     0
# keyword_trigger                 0
# start_text                      0
# half_text                       0
# canonical_link                  0
# _row_id                         0
# iran_count                      0
# iran_score                     36
# iran_sentiment                  0
# iranian_count                   0
# iranian_score                 138
# iranian_sentiment               0
# israel_israeli_count            0
# israel_israeli_score           70
# israel_israeli_sentiment        0
# hormuz_count                    0
# hormuz_score                  213
# hormuz_sentiment                0
# supreme_leader_count            0
# supreme_leader_score          320
# supreme_leader_sentiment        0
# tehran_count                    0
# tehran_score                  235
# tehran_sentiment                0
# trump_count                     0
# trump_score                   166
# trump_sentiment                 0
# us_united_states_count          0
# us_united_states_score         36
# us_united_states_sentiment      0
# title_score                     0
# title_sentiment                 0
# full_text_score                 0
# full_text_sentiment             0
# start_text_score                0
# start_text_sentiment            0
# half_text_score                 0
# half_text_sentiment             0
# title_article_diff              0
# title_article_diff_label        0
# dtype: int64

# %%
order = [
    'very negative',
    'negative',
    'somewhat negative',
    'neutral',
    'somewhat positive',
    'positive',
    'very positive'
]

sns.countplot(y='iran_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='iran_sentiment'>

# %%
sns.countplot(y='israel_israeli_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='israel_israeli_sentiment'>

# %%
sns.countplot(y='supreme_leader_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='supreme_leader_sentiment'>

# %%
sns.countplot(y='hormuz_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='hormuz_sentiment'>

# %%
sns.countplot(y='iranian_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='iranian_sentiment'>

# %%
sns.countplot(y='trump_sentiment', hue='publisher', data=df, order=order)
# Out:
# <Axes: xlabel='count', ylabel='trump_sentiment'>

# %%
sentiment_cols = [
    'iran_sentiment',
    'iranian_sentiment',
    'israel_israeli_sentiment',
    'hormuz_sentiment',
    'supreme_leader_sentiment',
    'tehran_sentiment',
    'trump_sentiment',
    'us_united_states_sentiment',
    'full_text_sentiment',
    'start_text_sentiment',
    'half_text_sentiment',
    'title_sentiment'


]

df_long = df.melt(
    id_vars='publisher',
    value_vars=sentiment_cols,
    var_name='entity',
    value_name='sentiment'
)
df_long = df_long[df_long['sentiment'] != 'no matches']

df_pct = (
    df_long.groupby(['publisher', 'entity', 'sentiment'])
           .size()
           .reset_index(name='count')
)

df_pct['percent'] = (
    df_pct.groupby(['publisher', 'entity'])['count']
          .transform(lambda x: 100 * x / x.sum())
)


g = sns.catplot(
    data=df_pct,
    x='percent',
    y='sentiment',
    hue='publisher',
    col='entity',
    kind='bar',
    col_wrap=2,
    height=4,
    sharex=False, 
    order=order
)

g.fig.suptitle('Sentiment Distribution by Entity and Publisher', y=1.02)
# Out:
# Text(0.5, 1.02, 'Sentiment Distribution by Entity and Publisher')

# %%
df_time = (
    df.groupby(['collection_date', 'publisher'])['full_text_score']
      .mean()
      .reset_index()
)

plt.figure(figsize=(12,6))

sns.lineplot(
    data=df_time,
    x='collection_date',
    y='full_text_score',
    hue='publisher'
)

plt.xticks(rotation=45)
plt.title('Average Iran Sentiment Over Time')
plt.tight_layout()

# %%
df_long = df.melt(
    id_vars=['publisher', 'collection_date'],
    value_vars=sentiment_cols,
    var_name='entity',
    value_name='sentiment'
)

sentiment_map = {
    'very negative': -2,
    'negative': -1,
    'somewhat negative': -0.5,
    'neutral': 0,
    'somewhat positive': 0.5,
    'positive': 1,
    'very positive': 2
}

df_long['score'] = df_long['sentiment'].map(sentiment_map)
df_long['collection_date'] = pd.to_datetime(df_long['collection_date']).dt.date

df_time = (
    df_long.groupby(['collection_date', 'publisher', 'entity'])['score']
           .mean()
           .reset_index()
)  

sns.lineplot(
    data=df_time,
    x='collection_date',
    y='score',
    hue='entity'
)
# Out:
# <Axes: xlabel='collection_date', ylabel='score'>

# %%
df_time['collection_date'] = pd.to_datetime(df_time['collection_date'], errors='coerce')

df_time = df_time.sort_values(['publisher', 'entity', 'collection_date'])

df_time['smoothed'] = (
    df_time.groupby(['publisher', 'entity'])['score']
           .transform(lambda x: x.rolling(3, min_periods=1).mean())
)

g = sns.relplot(
    data=df_time,
    x='collection_date',
    y='smoothed',
    hue='publisher',
    col='entity',
    kind='line',
    col_wrap=2,
    height=4
)

for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45)

g.fig.tight_layout()

# %% [markdown]
# ### 2.2 Feature Engineering
#
# Create a variable that adds BMI with age.  Also multiply that sum by 3 if a smoker.

# %%
# Create numeric variable for age and twice bmi
df['3ptindex'] = (df['age'] + df['bmi'] ) * ( 2 * df['smoker_e'] + 1)

# %% [markdown]
# ## Section 3. Feature Selection and Justification
# ### 3.1 Choose features and target
#
#
#
# Case 1:
# input features: "age", "bmi", "children", "charges", "smoker_e", "sex_e", "region_northeast", "region_northwest", "region_southeast", "region_southwest"
# target: "charges"
#
# Case 2:
# input features: '3ptindex'
# target: "charges"

# %% [markdown]
# ### 3.2 Define X and y
#
# Assign input features to X a pandas DataFrame with 1 or more input features
# Assign target variable to y (as applicable) - a pandas Series with a single target feature

# %%
# Define input features (X) and target (y) 
# All numberic features in the data frame.  Also don't inlude "bmi_age".
# Target: charges 

X1 = df.drop(columns=['charges', 'sex', 'smoker', '3ptindex'])  # Features
y1 = df['charges']  # Target

X2 = df[['3ptindex']]  # Features
y2 = df['charges']  # Target

# %%
# X1 Inputes 
X1.head()
# Out:
#    age     bmi  children  smoker_e  sex_e  region_northeast  region_northwest  \
# 0   19  27.900         0         1      1                 0                 0
# 1   18  33.770         1         0      0                 0                 0
# 2   28  33.000         3         0      0                 0                 0
# 3   33  22.705         0         0      0                 0                 1
# 4   32  28.880         0         0      0                 0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
# X2 Inputes 
X2.head()
# Out:
#    3ptindex
# 0   140.700
# 1    51.770
# 2    61.000
# 3    55.705
# 4    60.880

# %% [markdown]
# ### Reflection 2 and 3:
# - This dataset just had a handful of inputs to choose from.  I elected to add age and bmi then multiply that sum by 3 if a smoker as case 2.
# - I also decided to include all inputs in case 1 to compare the results to my single engineered input.

# %% [markdown]
# ## Section 4. Train a Regression Model (Linear Regression)
#
#
# Split the data into training and test sets.
#
# ### 4.1 Split the Data

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=123)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=123)

# %% [markdown]
# ### 4.2 Train and Evaluate Linear Regression Models (all 4 cases)
# Create and train all 4 cases.

# %%
lr_model1 = LinearRegression().fit(X1_train, y1_train)
lr_model2 = LinearRegression().fit(X2_train, y2_train)

# Predictions

y1_pred_train = lr_model1.predict(X1_train)
y1_pred_test = lr_model1.predict(X1_test)

y2_pred_train = lr_model2.predict(X2_train)
y2_pred_test = lr_model2.predict(X2_test)

# %% [markdown]
# ### 4.3 Evaluate Model Performance

# %%
print("Case 1: Training R²:", r2_score(y1_train, y1_pred_train))
print("Case 1: Test R²:", r2_score(y1_test, y1_pred_test))
print("Case 1: Test RMSE:", mean_squared_error(y1_test, y1_pred_test))
print("Case 1: Test MAE:", mean_absolute_error(y1_test, y1_pred_test))
# Out:
# Case 1: Training R²: 0.7376151899509507
# Case 1: Test R²: 0.8001744488359046
# Case 1: Test RMSE: 30552437.41652549
# Case 1: Test MAE: 4013.100618113485

# %%
residuals = y1_test - y1_pred_test
plt.scatter(y1_pred_test, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claim")
plt.ylabel("Residuals")
plt.title("Case 1 Linear Residual Plot")
plt.show()

# %%
print("Case 2: Training R²:", r2_score(y2_train, y2_pred_train))
print("Case 2: Test R²:", r2_score(y2_test, y2_pred_test))
print("Case 2: Test RMSE:", mean_squared_error(y2_test, y2_pred_test))
print("Case 2: Test MAE:", mean_absolute_error(y2_test, y2_pred_test))
# Out:
# Case 2: Training R²: 0.7454459600374025
# Case 2: Test R²: 0.824765332284362
# Case 2: Test RMSE: 26792600.783025622
# Case 2: Test MAE: 3659.4811199826368

# %%
plt.scatter(X2_test, y2_test, color='blue', label='Actual')
plt.scatter(X2_test, y2_pred_test, color='red', label='Predicted (Linear)')
plt.legend()
plt.title("Case 2 - Linear Regression: 3ptindex vs Claims")
plt.show()

# %%
residuals = y2_test - y2_pred_test
plt.scatter(y2_pred_test, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claim")
plt.ylabel("Residuals")
plt.title("Case 2 Linear Residual Plot")
plt.show()

# %% [markdown]
# ### Reflection 4:
# Compare the train vs test results for each.
#
#
# | Model Type        | Case   | Features Used                 | Training R² | Test R²   | RMSE     | MAE    | Notes |
# |-------------------|--------|-------------------------------|-------------|-----------|----------|--------|-------|
# | Linear Regression | Case 1 | all features                  | 0.7376      | 0.8001    | 30552437 | 4013   | -     |
# | Linear Regression | Case 2 | 3ptindex                      | 0.7454      | 0.8247    | 26792600 | 3659   | -     |
#
#
# - Did Case 1 overfit or underfit? Case 1 is in the nominal range.
# - Did Case 2 overfit or underfit? Case 2 is in the nominal range.
#
#
# ### Adding Age + BMI * (2 * Smoker + 1)
#
# - Did adding 3pt index improve the model: The model improved measurably from Case 1 to Case 2.
# - Propose a possible explanation (consider how age might affect ticket price, and whether the data supports that):  The 3ptindex formula keeps non-smoker claims as is in determining claims.  But if someone is a smoker it amplifies the age and bmi by 3 times.  This helps the linear regression with these higher values.
# - At first I just had 2 times, but I tried 3 times and the results were better.
# - I did not need to use the other parameters either and still achieved better results.
# - I wanted just a single variable to see the plot and in some ways stumbled into a great model.

# %% [markdown]
# ## Section 5. Compare Alternative Models

# %% [markdown]
# ### 5.1 Ridge Regression (L2 penalty)

# %%
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X1_train, y1_train)
y_pred_ridge = ridge_model.predict(X1_test)

# %%
residuals = y1_test - y_pred_ridge
plt.scatter(y_pred_ridge, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claims")
plt.ylabel("Residuals")
plt.title("Case 1 Ridge Regression Residual Plot")
plt.show()

# %% [markdown]
# ### 5.2 Elastic Net (L1 + L2 combined)

# %%
elastic_model = ElasticNet(alpha=0.3, l1_ratio=0.5)
elastic_model.fit(X1_train, y1_train)
y_pred_elastic = elastic_model.predict(X1_test)

# %%
residuals = y1_test - y_pred_elastic
plt.scatter(y_pred_elastic, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claim")
plt.ylabel("Residuals")
plt.title("Case 1 Elastic Net Residual Plot")
plt.show()

# %% [markdown]
# ### 5.3 Polynomial Regression

# %%
# Set up the poly inputs
poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X1_train)
X_test_poly = poly.transform(X1_test)

# %%
# Use the poly inputs in the LR model
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y1_train)
ycase1_pred_poly = poly_model.predict(X_test_poly)

# %%
residuals = y1_test - ycase1_pred_poly
plt.scatter(ycase1_pred_poly, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claim")
plt.ylabel("Residuals")
plt.title("Case 1 Ploy Cubic Residual Plot")
plt.show()

# %% [markdown]
# ### 5.4 Visualize Polynomial Cubic Fit (for 1 input feature)

# %%
# Set up the poly inputs
poly = PolynomialFeatures(degree=3)
X2_train_poly = poly.fit_transform(X2_train)
X2_test_poly = poly.transform(X2_test)

# %%
# Use the poly inputs in the LR model
poly_model = LinearRegression()
poly_model.fit(X2_train_poly, y2_train)
y2cubic_pred_poly = poly_model.predict(X2_test_poly)

# %%
plt.scatter(X2_test, y2_test, color='blue', label='Actual')
plt.scatter(X2_test, y2cubic_pred_poly, color='red', label='Predicted (Poly)')
plt.legend()
plt.title("Polynomial Cubic Regression: 3ptindex vs Claims")
plt.show()

# %%
residuals = y2_test - y2cubic_pred_poly
plt.scatter(ycase1_pred_poly, residuals)
plt.axhline(0, color='red')
plt.xlabel("Predicted Claim")
plt.ylabel("Residuals")
plt.title("Case 2 Ploy Cubic Residual Plot")
plt.show()

# %%
def report(name, y_true, y_pred):
    print(f"{name} R²: {r2_score(y_true, y_pred):.3f}")
    print(f"{name} RMSE: {mean_squared_error(y_true, y_pred):.2f}")
    print(f"{name} MAE: {mean_absolute_error(y_true, y_pred):.2f}\n")

report("Polynomial Cubic Case 2", y2_test, y2cubic_pred_poly)
# Out:
# Polynomial Cubic Case 2 R²: 0.824
# Polynomial Cubic Case 2 RMSE: 26873381.15
# Polynomial Cubic Case 2 MAE: 3686.53

# %% [markdown]
# ### 5.5 Reflection
# - What patterns does the cubic model seem to capture:  It is very hard to know for case 1 with all the inputs.  For case 2 it matched the data slightly better than linear regression.
# - Where does it perform well or poorly:  According to the residuals plot the result is very balanced for case 1.  I see some values on both sides of zero which is desirable. For case 2, there is still some balance, but it is not quite as good as case 1.
# - Did the polynomial fit outperform linear regression: Yes the R² value 0.888 for poly but 0.80 for Linear for case 1.  For case 2 the results were almost the same.
# - Where (on the graph or among which kinds of data points) does it fit best:  The prediction works well for smokers and non-smokers for case 1 and case 2.
#
# | Model Type    | Case   | Features Used                 | Test R²   | RMSE     | MAE    | Notes |
# |---------------|--------|-------------------------------|-----------|----------|--------|-------|
# | Linear        | Case 1 | All Inputs                    | 0.800     | 30552437 | 4013   | -     |
# | Poly Cubic    | Case 1 | All Inputs                    | 0.888     | 17093508 | 2772   | -     |
# | Linear        | Case 2 | 3ptindex                      | 0.825     | 26792600 | 3659   | -     |
# | Poly Cubic    | Case 2 | 3ptindex                      | 0.824     | 26873381 | 3686   | -     |

# %% [markdown]
# ### 5.6 Compare All Models

# %%
def report(name, y_true, y_pred):
    print(f"{name} R²: {r2_score(y_true, y_pred):.3f}")
    print(f"{name} RMSE: {mean_squared_error(y_true, y_pred):.2f}")
    print(f"{name} MAE: {mean_absolute_error(y_true, y_pred):.2f}\n")

report("Linear Case 1", y1_test, y1_pred_test)
report("Ridge Case 1", y1_test, y_pred_ridge)
report("ElasticNet Case 1", y1_test, y_pred_elastic)
report("Polynomial Cubic Case 1", y1_test, ycase1_pred_poly)
report("Linear Case 2", y2_test, y2_pred_test)
report("Polynomial Cubic Case 2", y2_test, y2cubic_pred_poly)
# Out:
# Linear Case 1 R²: 0.800
# Linear Case 1 RMSE: 30552437.42
# Linear Case 1 MAE: 4013.10
#
# Ridge Case 1 R²: 0.800
# Ridge Case 1 RMSE: 30632410.86
# Ridge Case 1 MAE: 4025.35
#
# ElasticNet Case 1 R²: 0.610
# ElasticNet Case 1 RMSE: 59577764.02
# ElasticNet Case 1 MAE: 5621.09
#
# Polynomial Cubic Case 1 R²: 0.888
# Polynomial Cubic Case 1 RMSE: 17093508.34
# Polynomial Cubic Case 1 MAE: 2772.78
#
# Linear Case 2 R²: 0.825
# Linear Case 2 RMSE: 26792600.78
# Linear Case 2 MAE: 3659.48
#
# Polynomial Cubic Case 2 R²: 0.824
# Polynomial Cubic Case 2 RMSE: 26873381.15
# Polynomial Cubic Case 2 MAE: 3686.53

# %% [markdown]
# | Model Type    | Case   | Features Used                 | Test R²   | RMSE     | MAE    | Notes |
# |---------------|--------|-------------------------------|-----------|----------|--------|-------|
# | Linear        | Case 1 | All Imputs                    | 0.800     | 30552437 | 4013   | -     |
# | Ridge         | Case 1 | All Imputs                    | 0.800     | 30632410 | 4025   | -     |
# | ElasticNet    | Case 1 | All Imputs                    | 0.610     | 59577764 | 5621   | -     |
# | Poly Cubic    | Case 1 | All Imputs                    | 0.888     | 17093508 | 2772   | -     |
# | Linear        | Case 2 | 3ptindex                      | 0.825     | 26792600 | 3659   | -     |
# | Poly Cubic    | Case 2 | 3ptindex                      | 0.824     | 26873381 | 3686   | -     |

# %% [markdown]
# ### Reflection 5.7:
# - There was just one model that outperformed and that was Polynomial Cubic on Case 1.  It did much better than all other models.  I'm not sure why as it is hard to visualize the data.
# - The other models did not perform better than Linear Regression on Case 1.
# - The Polynomial Cubic on Case 2 was slightly underperforming the Linear Regression on Case 2.

# %% [markdown]
# ## Section 6. Final Thoughts & Insights
#
# ### 6.1 Summarize Findings
#
#
# - What features were most useful?  The engineered feature 3ptindex was a very powerful predictor of claims.
#
# - What regression model performed best?  The Polynomial Cubic Model iterated on Case 1 had the best metrics.  The next best model was Case 2 and a simple Linear Regression.  It performed better than all of Case 1 except the Polynomial Cubic Model, and case 1 had all the inputs whereas Case 2 just had the single 3ptindex input.
# - You could see this in the residual graphics.  The Case 1 Cubic Model did have a quality distribution in the residual graphic.  To the eye the Case 2 Linear Model had the next best residual graphic.  Meaning the data points were around the zero line and not all on one side.  One also wants to see the points close to 0.
#
# ### 6.2 Discuss challenges faced.
# - I had a hard time visualizing all the inputs for case 1.  That is what drove me to find one variable so I could see the regression line and polynomial cubic line.
# - It was a challenge finding a single engineered variable that described the data.  But I did, and I am very pleased with the results.  It performed better that most of the models with all the inputs.
#
# ### 6.3 If you had more time, what would you try next?
# - I would try adding more inputs to Case 2.
# - I would try Ridge Regression and ElasticNet, but try varying the parameters.
# - I also would try voting.
